# %%
import sys

print(sys.version)
# Out:
# 3.7.10 (default, Feb 26 2021, 13:06:18) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# ## 1. 디스크립터 복습

# %% [markdown]
# ## 디스크립터 클래스와 활용 클래스 정의

# %%
class descriptor:
    
    def __init__(self, value):
        self.value = value
    # self : 디스크립터 객체
    # instance : 디스크립터를 사용하는 클래스의 객체
    def __get__(self, instance, owner):
        return self.value
    
    def __set__(self, instance, value):
        self.value = value
        
    def __delete__(self, instance):
        del self.value

# %%
class A:
    #data = 10
    data = descriptor(10)

# %% [markdown]
# ### 디스크립터 정의된 속성 내의 메소드 참조

# %%
a = A()
a.data
# Out:
# 10

# %% [markdown]
# ### 실제 데이터를 검색하는 방식

# %%
# == a.data
type(a).__dict__['data'].__get__(a, type(a))
# Out:
# 10

# %% [markdown]
# ## 실습
#
# ### 숫자를 저장하는 디스크립터 만들기
#
# 1. `__get__`, `__set__`, `__delete__` 구현
# 1. `__set__`을 통해 숫자를 저장한다.
# 1. 숫자는 호출할때마다 +1 증가
# 1. 숫자를 할당할때마다, 이전값에 더 합니다.(덮어쓰기 x)
# 1. 숫자를 지울떄는 최근에 추가한 수만큼만 제거합니다. (추가한 숫자들의 목록을 별도 저장)
# 1. 다음과 같이 작동해야합니다.

# %% [markdown]
# ### 디스크립터 클래스를 사용해서 특정 값 처리

# %%
class descriptor:
    # instance -> class A 인스턴스
    # self -> 디스크립터 클래스 인스턴스
    def __get__(self, instance, owner):
        instance.value += 1
        return instance.value
    
    def __set__(self, instance, value):
        if not hasattr(self, 'value'):
            instance.value = 0
            instance.recent = []
        instance.value += value
        instance.recent.append(value)
        
    def __delete__(self, instance):
        instance.value -= instance.recent[-1]
        instance.recent.pop()
        # 최근 추가된 값만큼만 마이너스(-)
        # 그리고 최근 추가된 리스트에서 제거

# %%
class A:
    number = descriptor()

# %%
a = A()
b = A()

# %%
a.__dict__
# Out:
# {}

# %%
b.__dict__
# Out:
# {}

# %% [markdown]
# ### 인스턴스에 속성 추가

# %%
a.number = 1
print(a.number)
# Out:
# 2

# %%
a.__dict__
# Out:
# {'value': 2, 'recent': [1]}

# %% [markdown]
# ### 두번째 인스턴스에도 속성추가

# %%
a.number = 10
b.number = 3
print(b.number)
# Out:
# 4

# %%
a.__dict__
# Out:
# {'value': 10, 'recent': [10]}

# %%
b.__dict__
# Out:
# {'value': 4, 'recent': [3]}

# %% [markdown]
# # 데이터 디스크립터  &  비 데이터 디스크립터
#
#
# -  데이터 디스크립터 : `__set__`, `__delete__`중 하나라도 구현이 되어있으면
#
# -  비 데이터 디스크립터 : `__get__` 만 구현되어 있다면

# %%
from inspect import isfunction, isdatadescriptor

# %%
isfunction(lambda x : x)
# Out:
# True

# %%
class ND:
    def __get__(self, instance, owner):
        pass

# %%
class DD:
    def __get__(self, instance, owner):
        pass
    
    def __set__(self, instance, onwer):
        pass

# %%
nd = ND()
dd = DD()

# %%
isdatadescriptor(nd), isdatadescriptor(dd)
# Out:
# (False, True)

# %% [markdown]
# # 2. 디스크립터 속성 탐색
#
# instance 속성 vs  class 속성

# %% [markdown]
# # 2.1 데이터 디스크립터로 속성을 정의한 경우

# %%
class DataDes:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        self.value = value
        
    def __get__(self, instance, owner):
        return self.value

# %%
class A:
    data = DataDes(3)

# %%
a = A()

# %%
a.data
# Out:
# 3

# %%
a.__dict__
# Out:
# {}

# %% [markdown]
# ### 객체 속성에 data 를 지정

# %%
a.__dict__['data'] = 9

# %% [markdown]
# ### 객체에서 data를 참조하지만 클래스 속성인 디스크립터만 참조

# %%
a.data
# Out:
# 3

# %%
a.__dict__
# Out:
# {'data': 9}

# %% [markdown]
# # 2.2 논데이터 디스크립터는 인스턴스의 dict보다 나중에 탐색

# %%
class nondata:
    def __init__(self):
        self.value = 3
        
    def __get__(self, instance, owner):
        return self.value
    

class A:
    nd = nondata()

# %%
a = A()

# %%
a.nd, a.__dict__
# Out:
# (3, {})

# %%
a.__dict__['nd'] = 100

# %%
a.nd
# Out:
# 100

# %%
type(a).__dict__['nd'].__get__(a, type(a))
# Out:
# 3

# %% [markdown]
# # 2.3 `__get__`이 없는 data descriptor는 본인을 리턴한다

# %%
class DD:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        self.value = value
        
    def __repr__(self):
        return '< HI >'

class A:
    data = DD(3)

# %%
a = A()

# %%
a.data
# Out:
# < HI >

# %%
a.data.value
# Out:
# 3

# %%
a.data.__class__ is DD
# Out:
# True

# %% [markdown]
# # 2.4 클래스 dict의 값이 인스턴스 dict, 데이터디스크립터 보다 늦게 탐색

# %%
class A:
    def __init__(self, value):
        self.a = value
        
    a = 10

# %%
a = A(3)

# %%
A.__dict__, a.__dict__
# Out:
# (mappingproxy({'__module__': '__main__',
#                '__init__': <function __main__.A.__init__(self, value)>,
#                'a': 10,
#                '__dict__': <attribute '__dict__' of 'A' objects>,
#                '__weakref__': <attribute '__weakref__' of 'A' objects>,
#                '__doc__': None}),
#  {'a': 3})

# %%
a.a
# Out:
# 3

# %% [markdown]
# # 2.5  상속인 경우 MRO 탐색

# %%
class DD:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        self.value = value
        
    def __get__(self, instance, owner):
        return self.value
    

class A:
    pass


class B:
    value = DD(100)
    
    
class C(A, B):
    pass

# %%
c = C()

# %%
type(c).__mro__
# Out:
# (__main__.C, __main__.A, __main__.B, object)

# %%
c.value
# Out:
# 100

# %%
class A:
    value = 10
    

class B:
    value = DD(100)
    

class C(A, B):
    pass

# %%
c = C()
type(c).__mro__
# Out:
# (__main__.C, __main__.A, __main__.B, object)

# %%
c.value
# Out:
# 10

# %% [markdown]
# # 3.  클래스 속성 탐색

# %% [markdown]
# ## 메타클라스에 디스크립터 적용

# %%
class md:
    def __init__(self, value):
        self.value = value
        
    def __get__(self, instance, owner):
        print("md get")
        return self.value
    
    def __set__(self, instance, value):
        print('md set')
        self.value = value
        

class Meta(type):
    d = md(3)

# %%
class A(metaclass=Meta):
    pass

# %%
A.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'A' objects>,
#               '__weakref__': <attribute '__weakref__' of 'A' objects>,
#               '__doc__': None})

# %%
A.d
# Out:
# md get
# 3

# %% [markdown]
# ## 메타클래스에 `__get__`이 있는 데이터 디스크립터가 클래스의 값보다 우선한다.

# %%
class A(metaclass=Meta):
    d = 123

# %%
A.d
# Out:
# md get
# 3

# %% [markdown]
# ## 메타클래스에 `__get__`이 없는 데이터디스크립터는 클래스의 속성보다 늦다.

# %%
class d1:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        self.value = value
        
    def __get__(self, instance, owner):
        return self.value
        
class m(type):
    value = d1(99)

# %%
class A(metaclass=m):
    value = 1

# %%
A.value
# Out:
# 99

# %% [markdown]
# # set, delete 작동

# %%
class DD:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        raise AttributeError('NO!')
        
    def __get__(self, instance, owner):
        return self.value

class A:
    value = DD(99999)
    
    def __setattr__(self, name, value):
        print('setattr')
        super().__setattr__(name, value)

# %%
a = A()

# %%
a.value
# Out:
# 99999

# %%
a.value = 123
# Out:
# setattr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-79441df8c4fa> in <module>
# ----> 1 a.value = 123
#
# <ipython-input-55-20ca1859a6a4> in __setattr__(self, name, value)
#      14     def __setattr__(self, name, value):
#      15         print('setattr')
# ---> 16         super().__setattr__(name, value)
#
# <ipython-input-55-20ca1859a6a4> in __set__(self, instance, value)
#       4
#       5     def __set__(self, instance, value):
# ----> 6         raise AttributeError('NO!')
#       7
#       8     def __get__(self, instance, owner):
#
# AttributeError: NO!

# %% [markdown]
# ###  클래스인 경우..

# %%
class DD:
    def __init__(self, value):
        self.value = value
        
    def __set__(self, instance, value):
        raise AttributeError('NO!')
        
    def __get__(self, instance, owner):
        return self.value

# %%
class M(type):
    value = DD(9123123)
    
    def __setattr__(self, name, value):
        print('class setattr')
        super().__setattr__(name, value)

# %%
class A(metaclass=M):
    pass

# %%
A.value
# Out:
# 9123123

# %%
A.value = 123123
# Out:
# class setattr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-857d3b8be399> in <module>
# ----> 1 A.value = 123123
#
# <ipython-input-60-424644715372> in __setattr__(self, name, value)
#       4     def __setattr__(self, name, value):
#       5         print('class setattr')
# ----> 6         super().__setattr__(name, value)
#
# <ipython-input-59-e0d2814c9b70> in __set__(self, instance, value)
#       4
#       5     def __set__(self, instance, value):
# ----> 6         raise AttributeError('NO!')
#       7
#       8     def __get__(self, instance, owner):
#
# AttributeError: NO!

# %% [markdown]
# ### delete

# %%
class DD:
    def __init__(self, value):
        self.value = value
        
    def __delete__(self, instance):
        raise AttributeError('NO!')
        
    def __get__(self, instance, owner):
        return self.value

class A:
    value = DD(99999)
    
    def __delattr__(self, name):
        print('detattr')
        super().__delattr__(name,)

# %%
a = A()

# %%
a.value
# Out:
# 99999

# %%
del a.value
# Out:
# detattr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-37b3b1383dd1> in <module>
# ----> 1 del a.value
#
# <ipython-input-64-ca2e0fa4bfde> in __delattr__(self, name)
#      14     def __delattr__(self, name):
#      15         print('detattr')
# ---> 16         super().__delattr__(name,)
#
# <ipython-input-64-ca2e0fa4bfde> in __delete__(self, instance)
#       4
#       5     def __delete__(self, instance):
# ----> 6         raise AttributeError('NO!')
#       7
#       8     def __get__(self, instance, owner):
#
# AttributeError: NO!

# %% [markdown]
# # 4. 디스크립터를 사용할때, 정보를 저장하는 위치

# %%
class DD:
    # self = DD Class 인스턴스
    # instance = 디스크립터를 사용하는 클래스의 인스턴스 
    def __set__(self, instance, value):
        pass
    
    def __delete__(self, instance):
        pass
    
    def __get__(self, instance, owner):
        pass
    
        
class A:
    value = DD()

# %% [markdown]
# # 4.1 디스크립터에 저장

# %%
class descriptor:
    def __init__(self, value):
        self.value = value
        
    def __get__(self, instance, owner):
        return self.value
    
    def __set__(self, instance, value):
        self.value = value
        
class A:
    value = descriptor(10)

# %%
a = A()
b = A()

# %%
a.value
# Out:
# 10

# %%
b.value
# Out:
# 10

# %%
a.value = 10000

# %%
a.value
# Out:
# 10000

# %%
b.value
# Out:
# 10000

# %%
class descriptor:
    def __init__(self, value):
        self.storage = {}
        
    def __get__(self, instance, owner):
        return self.storage[instance]
    
    def __set__(self, instance, value):
        self.storage[instance] = value
        
    def __delete__(self, instance):
        del self.storage[instance]

# %%
class A:
    aaa = descriptor(123)

# %%
a = A()
b = A()
c = A()

# %%
a.aaa = 111

# %%
a.aaa
# Out:
# 111

# %%
b.aaa = 222

# %%
c.aaa = 333

# %%
a.aaa, b.aaa, c.aaa
# Out:
# (111, 222, 333)

# %%
A.__dict__['aaa'].storage
# Out:
# {<__main__.A at 0x7f8ee434a890>: 111,
#  <__main__.A at 0x7f8ee434a750>: 222,
#  <__main__.A at 0x7f8ee436d590>: 333}

# %% [markdown]
# 클래스 A가 생성한 모든 인스턴스에서 'aaa'이름으로 지정된 속성 값들을
#
# 모두 가져올 수 있다.

# %% [markdown]
# # 단점

# %%
del a

# %%
A.__dict__['aaa'].storage
# Out:
# {<__main__.A at 0x7f8ee434a890>: 111,
#  <__main__.A at 0x7f8ee434a750>: 222,
#  <__main__.A at 0x7f8ee436d590>: 333}

# %%
import weakref

# %%
wk_b = weakref.ref(b)

# %%
del b

# %%
wk_b
# Out:
# <weakref at 0x7f8ee434bfb0; to 'A' at 0x7f8ee434a750>

# %% [markdown]
# ### 해결

# %%
from weakref import WeakKeyDictionary

# %%
dict_ = WeakKeyDictionary()

# %%
class A:
    pass

# %%
a = A()

# %%
dict_[a] = 123

# %%
dict_[a]
# Out:
# 123

# %%
len(dict_)
# Out:
# 1

# %%
del a

# %%
len(dict_)
# Out:
# 0

# %%
from weakref import WeakKeyDictionary


class descriptor:
    def __init__(self, value):
        self.storage = WeakKeyDictionary()
        
    def __get__(self, instance, owner):
        return self.storage[instance]
    
    def __set__(self, instance, value):
        self.storage[instance] = value
        
    def __delete__(self, instance):
        del self.storage[instance]

# %%
from collections import UserDict

class A(UserDict):
    d = descriptor(10)

# %%
a = A()

# %%
a.d = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-a41dfb0b9253> in <module>
# ----> 1 a.d = 10
#
# <ipython-input-100-97868dcce20d> in __set__(self, instance, value)
#      10
#      11     def __set__(self, instance, value):
# ---> 12         self.storage[instance] = value
#      13
#      14     def __delete__(self, instance):
#
# ~/anaconda3/lib/python3.7/weakref.py in __setitem__(self, key, value)
#     407
#     408     def __setitem__(self, key, value):
# --> 409         self.data[ref(key, self._remove)] = value
#     410
#     411     def copy(self):
#
# TypeError: unhashable type: 'A'

# %% [markdown]
# ## id를 사용

# %%
d = {1, 2, 3}

# %%
d
# Out:
# {1, 2, 3}

# %%
hash(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-b3b2d2048e4e> in <module>
# ----> 1 hash(d)
#
# TypeError: unhashable type: 'set'

# %%
a = {}

# %%
a[d]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-88277f0cbf05> in <module>
# ----> 1 a[d]
#
# TypeError: unhashable type: 'set'

# %%
a[id(d)] = 123

# %%
a
# Out:
# {140251690150080: 123}

# %%
from weakref import finalize

# %%
class B:
    pass

b = B()

# %%
finalize(b, print, '제거', '합니다')
# Out:
# <finalize object at 0x7f8ee3a7efa0; for 'B' at 0x7f8ee43f8950>

# %%
del b
# Out:
# 제거 합니다

# %% [markdown]
# # 4.2 인스턴스 속성에 저장하는 디스크립터

# %% [markdown]
# ## 디스크립터 클래스에서 값을 객체 속성에 할당
#
# - 객체 내의 속성을 하나만 정의
# - 여러 속성을 처리할 때는 이슈 발생

# %%
class dd:
    def __set__(self, instance, value):
        instance.data = value
        
    def __get__(self, instance, value):
        return instance.data
        
    def __delete__(self, instance):
        del instance.data

# %%
class A:
    d = dd()

# %% [markdown]
# ### 2 객체를 생성해 속성 정의

# %%
a = A()
b = A()

# %%
a.d = 123
b.d = 10

# %%
a.d, b.d
# Out:
# (123, 10)

# %% [markdown]
# ### 여러 개의 속성에 디스크립터를 만들 경우 부작용
#
# - 하나의 객체 속성에만 값을 저장
# - 여러 속성의 값이 하나의 객체 속성에 저장됨

# %%
class A:
    data1 = dd()
    data2 = dd()

# %%
a = A()

# %%
a.data1 = 123
a.data2 = 1999999

# %%
a.data1, a.data2
# Out:
# (1999999, 1999999)

# %%
a.__dict__
# Out:
# {'data': 1999999}

# %% [markdown]
# ## 여러 속성을 정의할 경우 각 속성별로 이름을 배정
#
# - __set_name__ 메소드를 정의해서 실제 속성이름을 가져와서 객체 속성의 이름으로 처리

# %%
class dd:
    def __set_name__(self, owner, name):
        self.name = name
    
    def __set__(self, instance, value):
        instance.__dict__[self.name] = value
        
    def __get__(self, instance, value):
        return instance.__dict__[self.name]
        
    def __delete__(self, instance):
        del instance.__dict__[self.name]

# %%
class A:
    data1 = dd()
    data2 = dd()

# %%
a = A()

# %%
a.data1 = 123
a.data2 = 321

# %%
a.data1, a.data2
# Out:
# (123, 321)

# %%
a.__dict__
# Out:
# {'data1': 123, 'data2': 321}

# %% [markdown]
# # 5. 디스크립터에 추가

# %% [markdown]
# # 5.1 디스크립터 클래스 정의할 때 초기화에서 타입 정의
#
# - 값을 갱신할 때 이 타입을 확인해서 처리함

# %%
class Validated:
    def __set_name__(self, owner, name):
        self.name = name

    def __init__(self, type_):
        self.type = type_
        
    def __set__(self, instance, value):
        if isinstance(value, self.type):
            instance.__dict__[self.name] = value
        else:
            raise AttributeError('NO')

# %%
class A:
    num1 = Validated(int)
    num2 = Validated(float)

# %%
a = A()

# %%
a.num1 = 123
a.num2 = 1.0

# %%
a.num1, a.num2
# Out:
# (123, 1.0)

# %%
a.num1 = 1.0
a.num2 = 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-1b2e36bdb176> in <module>
# ----> 1 a.num1 = 1.0
#       2 a.num2 = 123
#
# <ipython-input-89-fdb6265e2289> in __set__(self, instance, value)
#      10             instance.__dict__[self.name] = value
#      11         else:
# ---> 12             raise AttributeError('NO')
#
# AttributeError: NO

# %% [markdown]
# # 5.2  특정 함수를 한번만 실행하도록 만들기

# %%
class lazy:
    def __init__(self, func):
        self.func = func
        
    def __get__(self, instance, owner):
        print("한번만 실행")
        value = self.func(instance)
        instance.__dict__[self.func.__name__] = value
        return value

# %%
class A:
    def __init__(self, value):
        self.value = value

    @lazy
    def data(self):
        return self.value * 10

# %%
a = A(111)

# %%
a.data
# Out:
# 한번만 실행
# 1110

# %%
a.data
# Out:
# 1110

# %%
a.data
# Out:
# 1110

# %% [markdown]
# # 5.3  리드온리

# %%
class descriptor:
    def __init__(self, value):
        self.value = value
    
    def __get__(self, instance, onwer):
        return self.value

    def __set__(self, instance, value):
        raise AttributeError('No')

# %%
class A:
    d = descriptor(10)

# %%
a = A()

# %%
a.d
# Out:
# 10

# %%
a.__dict__
# Out:
# {}

# %%
a.d = 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-737e056a4358> in <module>
# ----> 1 a.d = 123
#
# <ipython-input-101-c5ddc7287bb2> in __set__(self, instance, value)
#       7
#       8     def __set__(self, instance, value):
# ----> 9         raise AttributeError('No')
#
# AttributeError: No

# %%
a.__dict__
# Out:
# {}

# %% [markdown]
# # 5.4 상수

# %%
class Constant:
    def __init__(self, value):
        self.value = value
        
    def __get__(self, instance, owner):
        return self.value
    
    def __set__(self, instance, value):
        raise AttributeError('no')
        
    def __delete__(self, instance):
        raise AttributeError('no')

# %%
class ConsDataMixin:
    PI = Constant(3.1415)
    e = Constant(2.71828)

# %%
class MathMeta(type, ConsDataMixin):
    pass

# %%
class Math(ConsDataMixin, metaclass=MathMeta):
    pass

# %%
Math.PI
# Out:
# 3.1415

# %%
Math.PI = 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-dc2538773b26> in <module>
# ----> 1 Math.PI = 123
#
# <ipython-input-108-b9ae6852fba3> in __set__(self, instance, value)
#       7
#       8     def __set__(self, instance, value):
# ----> 9         raise AttributeError('no')
#      10
#      11     def __delete__(self, instance):
#
# AttributeError: no

# %%
math = Math()

# %%
math.PI
# Out:
# 3.1415

# %%
math.PI = 123
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-361521b04b72> in <module>
# ----> 1 math.PI = 123
#
# <ipython-input-108-b9ae6852fba3> in __set__(self, instance, value)
#       7
#       8     def __set__(self, instance, value):
# ----> 9         raise AttributeError('no')
#      10
#      11     def __delete__(self, instance):
#
# AttributeError: no

# %% [markdown]
# `__getattribute__`, `__getattr__`, `__setattr__`
