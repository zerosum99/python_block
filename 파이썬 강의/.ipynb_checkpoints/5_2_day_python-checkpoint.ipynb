# %% [markdown]
# # 1. 점 연산자로 접근

# %% [markdown]
# ## 객체 속성에 접근할때 발동하는 스페셜 메소드
#
# `__getattribute__` 겟 어트리뷰트
#
# `__getattr__` > 겟어트리
#
# `__setattr__`
#
# `__delattr__`

# %% [markdown]
# #  1.1 점 연산자 확인 `__getattribute__`
#
# 속성을 탐색

# %% [markdown]
# ## 클래스에 점 연산로 접근하는 스페셜 메소드를 재정의

# %%
class A:
    x = 3
    def __getattribute__(self, name):
        print("getattribute!!!")
        return super().__getattribute__(name)

# %% [markdown]
# ## 인스턴스를 만들어서 인스턴스에 속성을 추가한다

# %%
a = A()
a.y = 123

# %% [markdown]
# ## 인스턴스를 확인하면 클래스의 점 연산자가 실행된다

# %%
a.__dict__
# Out:
# getattribute!!!
# {'y': 123}

# %% [markdown]
# ## 클래스의 속성을 확인한다

# %%
type(a)
# Out:
# __main__.A

# %%
A.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'x': 3,
#               '__getattribute__': <function __main__.A.__getattribute__(self, name)>,
#               '__dict__': <attribute '__dict__' of 'A' objects>,
#               '__weakref__': <attribute '__weakref__' of 'A' objects>,
#               '__doc__': None})

# %%
type(a).__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'x': 3,
#               '__getattribute__': <function __main__.A.__getattribute__(self, name)>,
#               '__dict__': <attribute '__dict__' of 'A' objects>,
#               '__weakref__': <attribute '__weakref__' of 'A' objects>,
#               '__doc__': None})

# %% [markdown]
# ## 클래스 속성을 접근

# %%
a.x
# Out:
# getattribute!!!
# 3

# %% [markdown]
# ## 인스턴스 속성을 접근

# %%
a.y
# Out:
# getattribute!!!
# 123

# %%
print(a.x)
print(a.y)
# Out:
# getattribute!!!
# 3
# getattribute!!!
# 123

# %% [markdown]
# ## 상위 클래스를 정의하고 상속을 받아서 하위 속성을 처리

# %%
import warnings


class Private:
    def __getattribute__(self, name, perm=False):
        if not perm:
            warnings.warn("속성에 접근할 수 없습니다.")
            return None
        return super().__getattribute__(name)

    
class ScretBox(Private):
    pass

# %% [markdown]
# ## 인스턴스를 만들고 인스턴스 속성을 추가

# %%
a = ScretBox()
a.x = 3

# %% [markdown]
# ## 접근할 수 없도록 처리했으므로 warning 처리됨

# %%
a.x
# Out:
# C:\Users\06411\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: 속성에 접근할 수 없습니다.
#   import sys

# %%
a.__dict__
# Out:
# C:\Users\06411\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: 속성에 접근할 수 없습니다.
#   import sys

# %% [markdown]
# ## 클래스로 접근할 경우에는 워닝이 발생하지 않음

# %%
type(a)
# Out:
# __main__.ScretBox

# %%
type(a).__dict__
# Out:
# mappingproxy({'__module__': '__main__', '__doc__': None})

# %% [markdown]
# ## 인스턴스 속성을 접근할 때 perm에 true 접근하면 워닝이 사라짐

# %%
type(a).__getattribute__(a, '__dict__', True)
# Out:
# {'x': 3}

# %% [markdown]
# ## 부분함수를 이용해서 처리하면 퍼미션값부터 넣고 실제 인스턴스와 변수명을 넣으면 처리됨

# %%
from functools import partial

perm_a = partial(type(a).__getattribute__, perm=True)
print('partial 이용 : ',perm_a(a, 'x'))
# Out:
# partial 이용 :  3

# %% [markdown]
# # 1.2  점연산에서 예외가 발생처리 : `__getattr__`
#
# 객체 속성을 찾을때...
# **가장 마지막에 실행**

# %% [markdown]
# ## 클래스 정의할 때 점연산자에 예외 처리부분만 추가

# %%
import warnings


class A:
    def __getattr__(self, name):
        warnings.warn("값이 없습니다. 디폴트값을 넘깁니다.")
        return 3

# %% [markdown]
# ## 인스턴스를 만들고 내부 속성 추가

# %%
a = A()
a.var = 123

# %% [markdown]
# ## 있는 속성은 점연산자로 접근이 되므로 출력이 됨

# %%
print('a.var', a.var)
# Out:
# a.var 123

# %% [markdown]
# ## 없는 속성은 점연산자로 처리가 되지 않으므로 `__getattr__` 메소드를 호출해서 처리

# %%
print('a.xxx', a.xxx)
# Out:
# a.xxx 3
# C:\Users\06411\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: 값이 없습니다. 디폴트값을 넘깁니다.

# %% [markdown]
# # 1.3  점연산자 두개의 메소드 정의  `__getattribute__` vs `__getattr__`

# %% [markdown]
# ## 클래스에 점 연산자 모든 메소드 정의

# %%
class A:
    def __getattribute__(self, name):
        print("getattribute")
        return super().__getattribute__(name)
    
    def __getattr__(self, name):
        print("getattr")
        return '없습니다.'

# %% [markdown]
# ## 인스턴스 생성

# %%
a = A()

# %% [markdown]
# ## 없는 속성 접근

# %%
print(a.no)
# Out:
# getattribute
# getattr
# 없습니다.

# %% [markdown]
# ## 속성 추가

# %%
a.var = 1

# %% [markdown]
# ## 있는 속성 접근

# %%
print(a.var)
# Out:
# getattribute
# 1

# %% [markdown]
# # 1.4 메타 클래스에 점연산자 추가해서  class 속성을 탐색할때

# %% [markdown]
# ## 메타 클래스 정의

# %%
class Meta(type):
    def __getattribute__(self, name):
        return "classattribute"
    
    def __getattr__(self, name):
        return "classattr"

# %% [markdown]
# ## 클래스에 메타클래스 변경

# %%
class A(metaclass=Meta):
    pass

# %% [markdown]
# ## 없는 클래스 속성 접근

# %%
print(A.b)
# Out:
# classattribute

# %%
a = A()
# Out:
# getattribute
# getattribute
# getattribute
# getattribute
# getattribute
# getattribute

# %%
try :
    print(a.b)
except Exception as e :
    print(e)
# Out:
# 'A' object has no attribute 'b'

# %% [markdown]
# # 2. 점 연산자로 갱신 `__setattr__`
#
# 속성에 객체를 할당할때

# %% [markdown]
# ## 2.1  점 연산자로 갱신만 하기

# %%
class A:
    def __setattr__(self, name, value):
        # return 필요 없음
        print("setattr!!")
        self.__dict__[name] = value

# %%
a = A()

# %%
a.var = 3
# Out:
# setattr!!

# %%
print(a.var)
# Out:
# 3

# %% [markdown]
# # 2.2 모듈에 점연산로 갱신하기  `__setattr__` 적용

# %% [markdown]
# ## 모듈도 클래스로 인식하므로 실제 모듈을 클래스화해서 처리

# %%
# %%writefile d7.py

import sys
from types import ModuleType


class MyModule(ModuleType):
    def __repr__(self):
        return 'MyModule'
    
    def __setattr__(self, name, value):
        print(name, "세팅 불가")
        
    @staticmethod
    def func(a, b):
        pass
        
def func(a, b):
    pass
        
sys.modules[__name__].__class__ = MyModule
# Out:
# Overwriting d7.py

# %% [markdown]
# ## 직전에 만든 모듈에 정보를 세팅하려면 실제 세팅이 안됨

# %%
# %%writefile d8.py

import d7

print(d7)
d7.a = 3
print(d7.a)
# Out:
# Overwriting d8.py

# %%
# !python d8.py
# Out:
# MyModule
# a 세팅 불가
# Traceback (most recent call last):
#   File "d8.py", line 6, in <module>
#     print(d7.a)
# AttributeError: module 'd7' has no attribute 'a'

# %% [markdown]
# # 3. 점 연산로 속성 제거 하기 `__delattr__`

# %%
class A:
    def __delattr__(self, name):
        print("지울 수 없습니다.")

# %%
a = A()
a.var = 3

# %%
print(a.var)
# Out:
# 3

# %%
del a.var # 여기서 __delattr__가 작동

print(a.var)
# Out:
# 지울 수 없습니다.
# 3

# %% [markdown]
# # 4. 스페셜메소드를 통한 속성 컨트롤
#
# ### 인스턴스를 생성할때 반지름을 입력받는 원 객체 / 원의 속성을 가지고 있는..
#
# > 반지름은 mutable
# > 그 외에 지름, 둘레, 넓이는 immutable

# %%
# %%writefile d10.py


import warnings

MUTABLE = ['radius']
IMMUTABLE = ['diameter', 'circumference', 'area']

class Circle:
    pi = 3.1415
    
    def __init__(self, r):
        self.radius = r
        
    def diameter(self):
        return self.radius * 2
    
    def circumference(self):
        return self.radius * self.pi * 2
    
    def area(self):
        return (self.radius ** 2) * self.pi
    
    def __setattr__(self, name, value):
        if name in IMMUTABLE:
            warnings.warn("불가")
        return super().__setattr__(name, value)
    
    # __delattr__ 추가
    

c = Circle(10)
print(c.radius)
print(c.diameter())
c.radius = 100
c.area = 123
# Out:
# Writing d10.py

# %%
# !python d10.py
# Out:
# 10
# 20
# d10.py:25: UserWarning: 불가
#   warnings.warn("불가")
